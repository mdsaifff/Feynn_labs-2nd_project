# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data= pd.read_csv("https://raw.githubusercontent.com/Pratyush-exe/FeyNN_Labs_proj_3/main/processed_magicBricks.csv")

# %%
data.head(n=50)
# Out:
#     Unnamed: 0  Unnamed: 0.1       city  ...  Couple  SingleProfessionals  Students
# 0            0             0     Mumbai  ...       1                    0         0
# 1            1             1     Mumbai  ...       1                    0         0
# 2            2             4     Mumbai  ...       1                    0         0
# 3            3             3     Mumbai  ...       1                    0         0
# 4            4             4     Mumbai  ...       1                    0         0
# 5            5             5     Mumbai  ...       1                    1         0
# 6            6             6     Mumbai  ...       1                    0         0
# 7            7             7     Mumbai  ...       1                    0         0
# 8            8             8     Mumbai  ...       1                    0         0
# 9            9             9     Mumbai  ...       1                    0         0
# ...

# %%
data.city.value_counts(normalize=True)
# Out:
# Chennai             0.057252
# Pune                0.057252
# Hyderabad           0.051527
# Vadodara            0.051527
# Mumbai              0.049618
# Thane               0.049618
# Bangalore           0.047710
# Bhubaneswar         0.043893
# Jaipur              0.043893
# Kolkata             0.041985
# Gurgaon             0.041985
# Ghaziabad           0.040076
# Ahmedabad           0.040076
# Chandigarh          0.038168
# Coimbatore          0.032443
# Indore              0.032443
# Nagpur              0.030534
# Faridabad           0.030534
# Visakhapatnam       0.028626
# New-Delhi           0.024809
# Nashik              0.024809
# Ranchi              0.022901
# Bhopal              0.017176
# Delhi-N00000        0.017176
# Patna               0.015267
# Allahabad           0.009542
# Raipur              0.007634
# Surat               0.007634
# Mysore              0.007634
# Ludhiana            0.005725
# Varanasi            0.005725
# Guwahati            0.005725
# ...

# %%
f, ax = plt.subplots(figsize=(20,15)) 
data.city.value_counts(normalize=True).plot.barh()
plt.show()

# %%
f, ax = plt.subplots(figsize=(15,20)) 
data.city.value_counts(normalize=True)
data.city.value_counts(normalize=True).plot.pie()
plt.show()

# %%
plt.scatter (data.index, data ['water-availability'])
plt.xlabel('Water  Availability', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['status-of-electricity'])
plt.xlabel('Status of Electricity', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['furnishing'])
plt.xlabel('Furnishing', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['bedrooms'])
plt.xlabel('Bedrooms', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['bathrooms'])
plt.xlabel('Bathrooms', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['status'])
plt.xlabel('Status', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['neighborhood'])
plt.xlabel('Neighborhood', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['roads'])
plt.xlabel('Roads', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['safety'])
plt.xlabel('Safety', fontsize= 12)
plt.show()

# %%
plt.scatter (data.index, data ['cleanliness'])
plt.xlabel('Cleanliness', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['public-transport'])
plt.xlabel('Public Transport', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['parking'])
plt.xlabel('Parking', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['connectivity'])
plt.xlabel('Connectivity', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['traffic'])
plt.xlabel('Traffic', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['school'])
plt.xlabel('School', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['restaurants'])
plt.xlabel('Restaurants', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['hospital'])
plt.xlabel('Hospital', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['market'])
plt.xlabel('Market', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['locality-rating'])
plt.xlabel('Locality Rating', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['capacity'])
plt.xlabel('Capacity', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['towers'])
plt.xlabel('Towers', fontsize= 15)
plt.show()

# %%
plt.scatter (data.index, data ['units'])
plt.xlabel('Units', fontsize= 15)
plt.show()
